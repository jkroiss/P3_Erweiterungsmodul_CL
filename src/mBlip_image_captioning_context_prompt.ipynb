# %%
import pandas as pd
import torch
from PIL import Image
import urllib.request

from transformers import AutoProcessor, Blip2ForConditionalGeneration

# %% [markdown]
# ## Read data

# %%
from google.colab import drive
drive.mount('/content/drive')

path='/content/drive/My Drive/ErwModul_24/data/preprocessed_wit_1_percent_20_langs.tsv'
folder_path = '/content/drive/My Drive/ErwModul_24'
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv(path, sep='\t')
df
# Out:
#        Unnamed: 0 language                                          image_url  \
# 0               0       en  https://upload.wikimedia.org/wikipedia/commons...
# 1               1       en  http://upload.wikimedia.org/wikipedia/commons/...
# 2               2       en  https://upload.wikimedia.org/wikipedia/commons...
# 3               3       en  https://upload.wikimedia.org/wikipedia/commons...
# 4               4       en  https://upload.wikimedia.org/wikipedia/commons...
# ...           ...      ...                                                ...
# 16795       16795       vi  https://upload.wikimedia.org/wikipedia/commons...
# 16796       16796       vi  https://upload.wikimedia.org/wikipedia/commons...
# 16797       16797       vi  https://upload.wikimedia.org/wikipedia/commons...
# 16798       16798       vi  http://upload.wikimedia.org/wikipedia/commons/...
# 16799       16799       vi  https://upload.wikimedia.org/wikipedia/commons...
#
#                            caption_reference_description  \
# 0      Great Sleigh Drive (1678):Frederick William pu...
# 1      G9 crew: Stoker Drake at extreme right of pict...
# 2                                Huichol woman and child
# 3      Merner-Pfeiffer Hall part of the Conservatory ...
# 4      1917 advertisement featuring Lloyd as "Lonesom...
# ...                                                  ...
# 16795  Núi Sugarloaf, Rio de Janeiro được sử dụng cho...
# 16796                                      Septic river.
# 16797                            Phục nguyên P. grangeri
# 16798  Một góc thành phố Huế bị tàn phá trơ trụi. Ảnh...
# 16799          1 cặp chim sếu với chim non tại Velavadar
#
#                        page_title               section_title
# 0             Brandenburg-Prussia      Dutch and Scanian Wars
# 1                          HMS G9                        Loss
# 2                     Huichol art          The Huichol People
# 3      Baldwin Wallace University                 April Reign
# 4                    Harold Lloyd  Silent shorts and features
# ...                           ...                         ...
# 16795          The Amazing Race 2   Chặng 1 (Hoa Kỳ → Brasil)
# 16796                Ô nhiễm biển          Nguồn xả trực tiếp
# 16797                Platybelodon                       Mô tả
# 16798        Sự kiện Tết Mậu Thân                     Tại Huế
# 16799                   Sếu sarus              Yếu tố tử vong
#
# [16800 rows x 6 columns]

# %% [markdown]
# ## Load BLIP-2 model

# %%
# setup device to use
device = torch.device('cuda') if torch.cuda.is_available() else 'cpu'

# %%
# loads mBLIP pre-trained model
processor = AutoProcessor.from_pretrained('Gregor/mblip-mt0-xl')
model = Blip2ForConditionalGeneration.from_pretrained('Gregor/mblip-mt0-xl', torch_dtype=torch.float16)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/432 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/324 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/74.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/7.06k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/133k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.96G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/9.38G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]

# %%
model.to(device)
# Out:
# Blip2ForConditionalGeneration(
#   (vision_model): Blip2VisionModel(
#     (embeddings): Blip2VisionEmbeddings(
#       (patch_embedding): Conv2d(3, 1408, kernel_size=(14, 14), stride=(14, 14))
#     )
#     (encoder): Blip2Encoder(
#       (layers): ModuleList(
#         (0-38): 39 x Blip2EncoderLayer(
#           (self_attn): Blip2Attention(
#             (dropout): Dropout(p=0.0, inplace=False)
#             (qkv): Linear(in_features=1408, out_features=4224, bias=True)
#             (projection): Linear(in_features=1408, out_features=1408, bias=True)
#           )
#           (layer_norm1): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#           (mlp): Blip2MLP(
#             (activation_fn): GELUActivation()
#             (fc1): Linear(in_features=1408, out_features=6144, bias=True)
#             (fc2): Linear(in_features=6144, out_features=1408, bias=True)
#           )
#           (layer_norm2): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#   )
#   (qformer): Blip2QFormerModel(
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#     (dropout): Dropout(p=0.1, inplace=False)
#     (encoder): Blip2QFormerEncoder(
#       (layer): ModuleList(
#         (0): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (9): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (10): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (crossattention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=1408, out_features=768, bias=True)
#               (value): Linear(in_features=1408, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (11): Blip2QFormerLayer(
#           (attention): Blip2QFormerAttention(
#             (attention): Blip2QFormerMultiHeadAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): Blip2QFormerSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate_query): Blip2QFormerIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output_query): Blip2QFormerOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (language_projection): Linear(in_features=768, out_features=2048, bias=True)
#   (language_model): MT5ForConditionalGeneration(
#     (shared): Embedding(250112, 2048)
#     (encoder): MT5Stack(
#       (embed_tokens): Embedding(250112, 2048)
#       (block): ModuleList(
#         (0): MT5Block(
#           (layer): ModuleList(
#             (0): MT5LayerSelfAttention(
#               (SelfAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#                 (relative_attention_bias): Embedding(32, 32)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): MT5LayerFF(
#               (DenseReluDense): MT5DenseGatedActDense(
#                 (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wo): Linear(in_features=5120, out_features=2048, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): NewGELUActivation()
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-23): 23 x MT5Block(
#           (layer): ModuleList(
#             (0): MT5LayerSelfAttention(
#               (SelfAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): MT5LayerFF(
#               (DenseReluDense): MT5DenseGatedActDense(
#                 (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wo): Linear(in_features=5120, out_features=2048, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): NewGELUActivation()
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): MT5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (decoder): MT5Stack(
#       (embed_tokens): Embedding(250112, 2048)
#       (block): ModuleList(
#         (0): MT5Block(
#           (layer): ModuleList(
#             (0): MT5LayerSelfAttention(
#               (SelfAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#                 (relative_attention_bias): Embedding(32, 32)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): MT5LayerCrossAttention(
#               (EncDecAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): MT5LayerFF(
#               (DenseReluDense): MT5DenseGatedActDense(
#                 (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wo): Linear(in_features=5120, out_features=2048, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): NewGELUActivation()
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#         (1-23): 23 x MT5Block(
#           (layer): ModuleList(
#             (0): MT5LayerSelfAttention(
#               (SelfAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (1): MT5LayerCrossAttention(
#               (EncDecAttention): MT5Attention(
#                 (q): Linear(in_features=2048, out_features=2048, bias=False)
#                 (k): Linear(in_features=2048, out_features=2048, bias=False)
#                 (v): Linear(in_features=2048, out_features=2048, bias=False)
#                 (o): Linear(in_features=2048, out_features=2048, bias=False)
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (2): MT5LayerFF(
#               (DenseReluDense): MT5DenseGatedActDense(
#                 (wi_0): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wi_1): Linear(in_features=2048, out_features=5120, bias=False)
#                 (wo): Linear(in_features=5120, out_features=2048, bias=False)
#                 (dropout): Dropout(p=0.1, inplace=False)
#                 (act): NewGELUActivation()
#               )
#               (layer_norm): MT5LayerNorm()
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#         )
#       )
#       (final_layer_norm): MT5LayerNorm()
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (lm_head): Linear(in_features=2048, out_features=250112, bias=False)
#   )
# )

# %% [markdown]
# ## Generate results for English

# %%
captions_eng = []
for i in range(0, 793):
  img_url_en = df['image_url'][i]
  try:
    img_path_en, _ = urllib.request.urlretrieve(img_url_en)

    # load image
    image_en = Image.open(img_path_en).convert('RGB')
  except:
    continue
  prompt = 'Page Title: {}, Section Title: {}. Caption the image:'.format(df['page_title'][i], df['section_title'][i])

  inputs = processor(image_en, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_en = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_eng.append((df['caption_reference_description'][i],generated_text_en))

# %%
len(captions_eng)
# Out:
# 756

# %%
print(captions_eng)
# Out:
# [('Great Sleigh Drive (1678):Frederick William pursues Swedish troops across the frozen Curonian Lagoon; fresco by Wilhelm Simmler, ca. 1891', 'Een schilderij van een paard en een man die op een paard rijden.'), ('G9 crew: Stoker Drake at extreme right of picture standing-easy. A B Baby centre of back row of 5.', 'A group of sailors posing for a photo on a ship.'), ('Huichol woman and child', 'The Huichol People are a group of people who live in the northern part of the United'), ('Merner-Pfeiffer Hall part of the Conservatory of Music, which hosts the yearly Bach Festival', 'A large brick building with a snowy lawn.'), ('1917 advertisement featuring Lloyd as "Lonesome Luke", with Snub Pollard and Bebe Daniels', 'Silent shorts and features'), ('Root Rectangles to Generate diagonals for Dynamic Symmetry', 'a diagram showing the lines of a triangle with a triangle between'), ('MV Vogelsberg in the port of Freetown 1958', 'A large ship is sitting in a dock.'), ('Karatoa River near Mahasthangarh', 'Formation of land is a river, which flows through a valley.'), ('Wanderer W 24 1937', 'A green and white car is displayed on a display.'), ('Church of Scotland Offices, Edinburgh', 'A large building with a statue on the top.'), ("Grundtvig's Pavilion", 'Rønnebæksholm, Section of Grundvig Pavilion'), ('Turin today', 'Turin, Italy'), ('Members of the Ulster Volunteer Force march through Belfast, 1914', 'íomhá a ghlactar de shaighdiúirí a rith'), ('African National Congress constituency office in Sea Point, Cape Town, for Annelize van Wyk MP.', 'A building with a sign that says Sea Point.'), ('Building of Lovech Province administration', 'Azerbaijan'), ('A honey bee on a cornflower', 'A bee is sitting on top of a flower.'), ('Depiction of Samavasarana', 'दृश्य, जिसमें विभिन्न रंगों के चित्र दिखाए गए हैं'), ('Church of St. Nicholas', 'церковь'), ('Alexander Stephens, namesake of Stephens County', 'კაცი, რომელიც ზის სავარძელში, რომელსაც აქვს გრძელი'), ("The Museo Nacional Centro de Arte Reina Sofía (MNCARS) is Spain's national museum of 20th-century art, located in Madrid. The photo shows the old building with the addition of one of the contemporary glass towers to the exterior by Ian Ritchie Architects with the closeup of the modern art tower.", 'Early 20th century to 1930'), ('Members of convoy before departure', 'Ambush'), ('The team car', 'Imoto eyodwa eyodwa eyodwa eyodwa e'), ("Bernard O'Reilly headstone, St Johns Catholic Church, Kerry", 'Brisbane'), ('UCLA–USC rivalry football game at the Rose Bowl; the 2008 edition marked a return to the tradition of both teams wearing color jerseys.', 'A crowd of people watching a football game.'), ('Issue of 1890', 'a postage stamp with a picture of president james garfield'), ('Yamamotoyama in May 2009', 'sumo wrestlers in a ring with a rope'), ("Eagle Investment Systems' Wellesley office, renovated in 2018.", 'A large office with a sign that says "Eagle Investment Systems"'), ('Capitol Police Crown Victoria Police Interceptor automobile, 2012', 'A police car parked on the side of a street.'), ('A typical fixed install card terminal from 2006', 'A portable computer with a numeric display on it.'), ("Charles Follen McKim's Grand Staircase looking north, northwest seen from the Cross Hall photographed during the administration of Harry Truman before reconstruction.", "The McKim's new Grand Staircase is a very pretty and elegant"), ('A live opened scallop showing the internal anatomy: The pale orange circular part is the adductor muscle; the darker orange curved part is the "coral", a culinary term for the ovary or roe.', 'a person holding a shell of an oyster'), ('A street in Mdina, Malta named after Villegaignon.', 'Nicolas Durand de Villegaignon, known as Nicolas Durand de Villegaignon'), ('Commodore PET 2001 (1977)', 'Commodore International, Section Title: "Computers for the masses, not the classes".'), ('Contemporary arms of Princess Diana of Cadaval, Duchess of Cadaval & Anjou.', 'escudo'), ( ...

# %%
with open('/content/drive/My Drive/ErwModul_24/results/eng_context_transl.txt', 'w') as writeEngFile:
    for cap in captions_eng:
        writeEngFile.write(cap[0]+'\n')
        writeEngFile.write('|\n')
        writeEngFile.write(cap[1]+'\n|||\n')

# %%
captions_eng2 = []
for i in range(0, 793):
  img_url_en = df['image_url'][i]
  try:
    img_path_en, _ = urllib.request.urlretrieve(img_url_en)

    # load image
    image_en = Image.open(img_path_en).convert('RGB')
  except:
    continue

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in English:'.format(df['page_title'][i], df['section_title'][i])

  inputs = processor(image_en, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_en = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_eng2.append((df['caption_reference_description'][i],generated_text_en))

# %%
len(captions_eng)
# Out:
# 756

# %%
with open('/content/drive/My Drive/ErwModul_24/results/eng_context.txt', 'w') as writeEng2File:
    for cap in captions_eng2:
        writeEng2File.write(cap[0]+'\n')
        writeEng2File.write('|\n')
        writeEng2File.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate example for German

# %%
df_de = df[df['language'] == 'de'].reset_index()
df_de
# Out:
#      index  Unnamed: 0 language  \
# 0      840         840       de
# 1      841         841       de
# 2      842         842       de
# 3      843         843       de
# 4      844         844       de
# ..     ...         ...      ...
# 835   1675        1675       de
# 836   1676        1676       de
# 837   1677        1677       de
# 838   1678        1678       de
# 839   1679        1679       de
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  http://upload.wikimedia.org/wikipedia/commons/...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                      Südansicht der Znaimer Altstadt
# 1    Goldbronze-Relief der Stadt Uelzen vor dem Bra...
# 2    Haupthaus und Zehntscheune (rechts) des Gutes ...
# 3                            Chrom(III)-acetylacetonat
# 4    Schweizer Standardwagen-Zug aus Bern auf der L...
# ..                                                 ...
# 835                       Bahnhof Lauterecken-Grumbach
# 836  Wanderung mit Bienenvölkern in großem Maßstab ...
# 837        Militärischer Konvoi in der Region Katerini
# 838      Fahne des 13e RI in der Kathedrale von Nevers
# 839                                    Haus im Ennstal
#
#                       page_title                    section_title
# 0                         Znojmo                      Mittelalter
# 1                         Uelzen                      Mittelalter
# 2                          Dunau                       Geschichte
# 3      Chrom(III)-acetylacetonat                    Eigenschaften
# 4               Straßenbahn Iași                        Nach 1990
# ..                           ...                              ...
# 835                  Glantalbahn             Lauterecken-Grumbach
# 836                        Imker  Geschichte der Bienenwirtschaft
# 837  Griechische Militärdiktatur            Der Putsch auf Zypern
# 838    13e régiment d’infanterie         Fahne und Auszeichnungen
# 839            Haus (Steiermark)                        Geografie
#
# [840 rows x 7 columns]

# %%
captions_de = []
for i in range(0, 793):
  img_url_de = df_de['image_url'][i]
  try:
    img_path_de, _ = urllib.request.urlretrieve(img_url_de)

    # load image
    image_de = Image.open(img_path_de).convert('RGB')
  except:
    continue
  prompt = 'Titel der Seite: {}, Titel des Abschnitts: {}. Untertitel das Bild:'.format(df_de['page_title'][i], df_de['section_title'][i])

  inputs = processor(image_de, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_de = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_de.append((df_de['caption_reference_description'][i],generated_text_de))

# %%
len(captions_de)
# Out:
# 752

# %%
with open('/content/drive/My Drive/ErwModul_24/results/de_context_transl.txt', 'w') as writeDeFile:
    for cap in captions_de:
        writeDeFile.write(cap[0]+'\n')
        writeDeFile.write('|\n')
        writeDeFile.write(cap[1]+'\n|||\n')

# %%
captions_de2 = []
for i in range(0, 793):
  img_url_de = df_de['image_url'][i]
  try:
    img_path_de, _ = urllib.request.urlretrieve(img_url_de)

    # load image
    image_de = Image.open(img_path_de).convert('RGB')
  except:
    continue
  prompt = 'Page Title: {}, Section Title: {}. Caption the image in German:'.format(df_de['page_title'][i], df_de['section_title'][i])

  inputs = processor(image_de, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_de = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_de2.append((df_de['caption_reference_description'][i],generated_text_de))

# %%
len(captions_de2)
# Out:
# 751

# %%
with open('/content/drive/My Drive/ErwModul_24/results/de_context.txt', 'w') as writeDe2File:
    for cap in captions_de2:
        writeDe2File.write(cap[0]+'\n')
        writeDe2File.write('|\n')
        writeDe2File.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate example for Spanish

# %%
df_es = df[df['language'] == 'es'].reset_index()
df_es
# Out:
#      index  Unnamed: 0 language  \
# 0     2520        2520       es
# 1     2521        2521       es
# 2     2522        2522       es
# 3     2523        2523       es
# 4     2524        2524       es
# ..     ...         ...      ...
# 835   3355        3355       es
# 836   3356        3356       es
# 837   3357        3357       es
# 838   3358        3358       es
# 839   3359        3359       es
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0    "The Modern Gilpins" - Rivalidad entre el hunk...
# 1         Mapa de los países operadores del GTX Boxer.
# 2       Convento de Nuestra Señora del Carmen (Soria).
# 3     Min-Amon, fin del Nuevo Imperio (ca. 1200 a. C.)
# 4    Es una de tres grandes casas donde se aloja la...
# ..                                                 ...
# 835                            Bitis arietans (adulto)
# 836  Curva de la población humana que muestra el cr...
# 837                                  Mapa del Mar Egeo
# 838  Camión Mercedes-Benz Econic de recogida de des...
# 839         Pirámide de población de Australia en 2018
#
#                     page_title  \
# 0        Barnburners y Hunkers
# 1                    GTK Boxer
# 2           Catalina de Cristo
# 3                    Esteatita
# 4    Jorge Denegre Vaught Peña
# ..                         ...
# 835             Bitis arietans
# 836      Albert Allen Bartlett
# 837           Martino Zaccaria
# 838       Mercedes-Benz Econic
# 839            Generación Alfa
#
#                                          section_title
# 0                                              Hunkers
# 1                                             Usuarios
# 2                                          Fundaciones
# 3                                      Usos históricos
# 4    "Dos siglos de discursos patrióticos, colecció...
# ..                                                 ...
# 835                                        Descripción
# 836                            Crecimiento poblacional
# 837                     Reconquista bizantina de Quíos
# 838                                         Producción
# 839                                            Oceanía
#
# [840 rows x 7 columns]

# %%
captions_es = []
captions_es2 = []
for i in range(0, 800):
  img_url_es = df_es['image_url'][i]
  try:
    img_path_es, _ = urllib.request.urlretrieve(img_url_es)

    # load image
    image_es = Image.open(img_path_es).convert('RGB')
  except:
    continue

  prompt = 'Título de página: {}, Sección Título: {}. Capción de la imagen:'.format(df_es['page_title'][i], df_es['section_title'][i])
  inputs = processor(image_es, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_es = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_es.append((df_es['caption_reference_description'][i],generated_text_es))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Spanish:'.format(df_es['page_title'][i], df_es['section_title'][i])
  inputs = processor(image_es, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text_es = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_es2.append((df_es['caption_reference_description'][i],generated_text_es))

# %%
len(captions_es)
# Out:
# 762

# %%
with open('/content/drive/My Drive/ErwModul_24/results/es_context_transl.txt', 'w') as writefile:
    for cap in captions_es:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/es_context.txt', 'w') as writefile:
    for cap in captions_es2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate example for French

# %%
df_fr = df[df['language'] == 'fr'].reset_index()
df_fr
# Out:
#      index  Unnamed: 0 language  \
# 0     1680        1680       fr
# 1     1681        1681       fr
# 2     1682        1682       fr
# 3     1683        1683       fr
# 4     1684        1684       fr
# ..     ...         ...      ...
# 835   2515        2515       fr
# 836   2516        2516       fr
# 837   2517        2517       fr
# 838   2518        2518       fr
# 839   2519        2519       fr
#
#                                              image_url  \
# 0    http://upload.wikimedia.org/wikipedia/commons/...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    http://upload.wikimedia.org/wikipedia/commons/...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                    Oratoire de Catherine de Médicis.
# 1    Un Lancaster lâchant des paillettes qui formen...
# 2    Hessel Gerritsz - La Austrialia del Espiritu S...
# 3    Devitt avec le IWGP Junior Heavyweight Champio...
# 4    Gravure d'une monnaie frappée par la républiqu...
# ..                                                 ...
# 835  L'ancienne exploitation française d'Alizay emp...
# 836      Circulation routière aux abords de Hong Kong.
# 837  Occupation alliée du Japon. Défilé du 5th Roya...
# 838                                         Avril 2016
# 839  Constance d’Arles, nouvelle reine des Francs, ...
#
#                      page_title  \
# 0              Château de Blois
# 1         Reginald Victor Jones
# 2    Pedro Fernandes de Queirós
# 3                    Finn Bálor
# 4        République de Volterra
# ..                          ...
# 835                 Metsä Board
# 836    Histoire de l'automobile
# 837                        1946
# 838               Ko Kyeong-pyo
# 839          Robert II le Pieux
#
#                                          section_title
# 0                                           L'oratoire
# 1                                           Paillettes
# 2                                           Biographie
# 3                                             Palmarès
# 4                                     La menace pisane
# ..                                                 ...
# 835                                           Histoire
# 836                                Évolution du marché
# 837                                  Asie et Pacifique
# 838                               Spectacle de variété
# 839  Constance d'Arles, une reine à poigne (1003-1032)
#
# [840 rows x 7 columns]

# %%
captions_fr = []
captions_fr2 = []
for i in range(0, 800):
  img_url = df_fr['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Titre de la page: {}, Titre de la section: {}. Captionnez l\'image:'.format(df_fr['page_title'][i], df_fr['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_fr.append((df_fr['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in French:'.format(df_fr['page_title'][i], df_fr['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_fr2.append((df_fr['caption_reference_description'][i],generated_text))

len(captions_fr)
# Out:
# 759

# %%
with open('/content/drive/My Drive/ErwModul_24/results/fr_context_transl.txt', 'w') as writefile:
    for cap in captions_fr:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/fr_context.txt', 'w') as writefile:
    for cap in captions_fr2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate example for Italian

# %%
df_it = df[df['language'] == 'it'].reset_index()
df_it
# Out:
#      index  Unnamed: 0 language  \
# 0     3360        3360       it
# 1     3361        3361       it
# 2     3362        3362       it
# 3     3363        3363       it
# 4     3364        3364       it
# ..     ...         ...      ...
# 835   4195        4195       it
# 836   4196        4196       it
# 837   4197        4197       it
# 838   4198        4198       it
# 839   4199        4199       it
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  http://upload.wikimedia.org/wikipedia/commons/...
# 839  http://upload.wikimedia.org/wikipedia/commons/...
#
#                          caption_reference_description  \
# 0                Maria Maddalena con il vaso degli oli
# 1    Il viceré d'Italia, Eugenio di Beauharnais, su...
# 2    Il castello: cortile interno, parete est, anti...
# 3    Monumento memoriale a Gioacchino Ventura, Basi...
# 4    Luciano Zauri ai tempi della Fiorentina (stagi...
# ..                                                 ...
# 835  L'Agnello, mosaico nell'interno della cupola d...
# 836         Vecchio logo Brioni usato dal 1986 al 2016
# 837                    Dakosaurus, coccodrillo marino.
# 838  Alberto Del Rio durante un match in AAA nel gi...
# 839            San Antonio, la seconda città del Texas
#
#                                        page_title  \
# 0    Ex chiesa di Santa Maria Maddalena (Bergamo)
# 1                                Sesta coalizione
# 2              Fortificazioni medievali di Rovigo
# 3                              Gioacchino Ventura
# 4                                   Luciano Zauri
# ..                                            ...
# 835                           Concilio di Nicea I
# 836                              Brioni (azienda)
# 837                                     Titoniano
# 838                               Alberto Del Rio
# 839                                         Texas
#
#                                          section_title
# 0                                               Storia
# 1    Ritirata dei resti della Grande Armata e defez...
# 2                                          Il Castello
# 3                                            Biografia
# 4                                           Fiorentina
# ..                                                 ...
# 835  Calcolo della data della Pasqua cristiana in m...
# 836                                          1945-2011
# 837                                      †Talattosuchi
# 838   Asistencia Asesoría y Administración (2000–2005)
# 839                                              Città
#
# [840 rows x 7 columns]

# %%
captions_it = []
captions_it2 = []
for i in range(0, 800):
  img_url = df_it['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Titolo della pagina: {}, Titolo della sezione: {}. Capitulare l\'immagine:'.format(df_it['page_title'][i], df_it['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_it.append((df_it['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Italian:'.format(df_it['page_title'][i], df_it['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_it2.append((df_it['caption_reference_description'][i],generated_text))

len(captions_it)
# Out:
# 766

# %%
with open('/content/drive/My Drive/ErwModul_24/results/it_context_transl.txt', 'w') as writefile:
    for cap in captions_it:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/it_context.txt', 'w') as writefile:
    for cap in captions_it2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate example for Japanese

# %%
df_ja = df[df['language'] == 'ja'].reset_index()
df_ja
# Out:
#      index  Unnamed: 0 language  \
# 0     5040        5040       ja
# 1     5041        5041       ja
# 2     5042        5042       ja
# 3     5043        5043       ja
# 4     5044        5044       ja
# ..     ...         ...      ...
# 835   5875        5875       ja
# 836   5876        5876       ja
# 837   5877        5877       ja
# 838   5878        5878       ja
# 839   5879        5879       ja
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                      caption_reference_description       page_title  \
# 0                                     紙本墨書南番文字（原本）          シャー・ナーメ
# 1    愛媛県立今治西高等学校伯方分校（Blue pog.svg伯方分校）及びその周辺（愛媛県側）  愛媛県立今治西高等学校伯方分校
# 2                                    ハンプトン邸宅、1861年        ハンプトン国立史跡
# 3                   キャナルシティ博多停留所に進入する高千穂発のYOKAROバス        キャナルシティ博多
# 4                                              掩体壕      神奈川県立体育センター
# ..                                             ...              ...
# 835                                      バイアルスTL50           ホンダ・TL
# 836                      冬のファルマス湾に沈む夕日。カッスル・ドライブから   ファルマス (イングランド)
# 837                            Houtribsluizenの水門設備           レリスタット
# 838                                『岡崎朝報』社主時代の竹内京治             竹内京治
# 839                         ケネディ・センターはポトマック川沿いにある。        ワシントンD.C.
#
#     section_title
# 0          後代への影響
# 1              概観
# 2            19世紀
# 3              バス
# 4             その他
# ..            ...
# 835         バイアルス
# 836          スポーツ
# 837            地理
# 838         新聞社経営
# 839       舞台芸術・音楽
#
# [840 rows x 7 columns]

# %%
captions_ja = []
captions_ja2 = []
for i in range(0, 800):
  img_url = df_ja['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'ページタイトル: {},セクションタイトル: {}. 画像の字幕:'.format(df_ja['page_title'][i], df_ja['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ja.append((df_ja['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Japanese:'.format(df_ja['page_title'][i], df_ja['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ja2.append((df_ja['caption_reference_description'][i],generated_text))

len(captions_ja)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:3167: DecompressionBombWarning: Image size (103463401 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 753

# %%
with open('/content/drive/My Drive/ErwModul_24/results/ja_context_transl.txt', 'w') as writefile:
    for cap in captions_ja:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/ja_context.txt', 'w') as writefile:
    for cap in captions_ja2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate results for Russian

# %%
df_ru = df[df['language'] == 'ru'].reset_index()
df_ru
# Out:
#      index  Unnamed: 0 language  \
# 0     4200        4200       ru
# 1     4201        4201       ru
# 2     4202        4202       ru
# 3     4203        4203       ru
# 4     4204        4204       ru
# ..     ...         ...      ...
# 835   5035        5035       ru
# 836   5036        5036       ru
# 837   5037        5037       ru
# 838   5038        5038       ru
# 839   5039        5039       ru
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  http://upload.wikimedia.org/wikipedia/commons/...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0               Стандартные обозначения в треугольнике
# 1      Знаки различия генерала рода войск на воротнике
# 2        Здание мечети в пос. Урда (б. Ханская Ставка)
# 3            Возведение «Часов мира» на Александерплац
# 4                                  Церковь Сен-Сюльпис
# ..                                                 ...
# 835                         Средняя линия треугольника
# 836                      Александровские казармы, 1869
# 837  На здании педучилища, в котором учился Герой, ...
# 838                              Siphocampylus lucidus
# 839                                  Porsche 911 SC/RS
#
#                                      page_title  \
# 0                         Решение треугольников
# 1                            Генерал рода войск
# 2                               Букеевская Орда
# 3                            Часы мира (Берлин)
# 4                                         Лёмбр
# ..                                          ...
# 835                               Средняя линия
# 836                       Белгород-Днестровский
# 837                     Нехай, Даут Ереджибович
# 838  Список угрожаемых видов цветковых растений
# 839                                    Группа B
#
#                             section_title
# 0           Решение плоских треугольников
# 1                          Австро-Венгрия
# 2                               Население
# 3                                 История
# 4                                  Ссылки
# ..                                    ...
# 835            Средняя линия треугольника
# 836                                XX век
# 837                                Память
# 838  Семейство Калицеровые (Calyceraceae)
# 839                            Автомобили
#
# [840 rows x 7 columns]

# %%
captions_ru = []
captions_ru2 = []
for i in range(0, 800):
  img_url = df_ru['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Название страницы: {}, раздел Название: {}. Подзаголовок изображения:'.format(df_ru['page_title'][i], df_ru['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ru.append((df_ru['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Russian:'.format(df_ru['page_title'][i], df_ru['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ru2.append((df_ru['caption_reference_description'][i],generated_text))

len(captions_ru)
# Out:
# 763

# %%
with open('/content/drive/My Drive/ErwModul_24/results/ru_context_transl.txt', 'w') as writefile:
    for cap in captions_ru:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/ru_context.txt', 'w') as writefile:
    for cap in captions_ru2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate results for Polish

# %%
df_pl = df[df['language'] == 'pl'].reset_index()
df_pl
# Out:
#      index  Unnamed: 0 language  \
# 0     5880        5880       pl
# 1     5881        5881       pl
# 2     5882        5882       pl
# 3     5883        5883       pl
# 4     5884        5884       pl
# ..     ...         ...      ...
# 835   6715        6715       pl
# 836   6716        6716       pl
# 837   6717        6717       pl
# 838   6718        6718       pl
# 839   6719        6719       pl
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  http://upload.wikimedia.org/wikipedia/commons/...
#
#                          caption_reference_description  \
# 0    Lowell H. Smith i Lt. John P. Richter podczas ...
# 1    W 2007, w Wilnie, podczas ceremonii uhonorowan...
# 2    Willa ogrodowa (pl. Wolności 10) − siedziba Są...
# 3    Pomnik ofiar katastrofy lotniczej 16.09.1984 r...
# 4    Jaroslav Špaček w barwach Montréal Canadiens (...
# ..                                                 ...
# 835  Edykuła Grobu na rycinie Konrada von Grünenber...
# 836  PZL I-22 Iryda-M96 podzczas Air Fair w Bydgoszczy
# 837  Zajezdnia tramwajowa Helenówek, siedziba MKT w...
# 838                     Symbol Księżycowego Królestwa.
# 839  Flaga Królestwa Sardynii (1728–1802) z krzyżem...
#
#                                    page_title  \
# 0                      Tankowanie w powietrzu
# 1                  Jonas Mačiulis (koszykarz)
# 2                  Plac Wolności w Katowicach
# 3    Katastrofa lotnicza w Polskiej Nowej Wsi
# 4                             Jaroslav Špaček
# ..                                        ...
# 835                   Bazylika Grobu Świętego
# 836                            PZL I-22 Iryda
# 837                          Tramwaje w Łodzi
# 838                          Chibiusa Tsukino
# 839                        Królestwo Sardynii
#
#                                          section_title
# 0                                               Geneza
# 1                                          Osiągnięcia
# 2                                  Obiekty historyczne
# 3                                    Ofiary katastrofy
# 4                                   Kariera zawodnicza
# ..                                                 ...
# 835                             Konstantyn IX Monomach
# 836                                             Służba
# 837  Zajezdnie i inne budynki wyposażone w sieć tra...
# 838              Księżniczka Usagi Small Lady Serenity
# 839                                         XVIII wiek
#
# [840 rows x 7 columns]

# %%
captions_pl = []
captions_pl2 = []
for i in range(0, 800):
  img_url = df_pl['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Tytuł strony: {}, Sekcja Tytuł: {}. Podpisz obraz:'.format(df_pl['page_title'][i], df_pl['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_pl.append((df_pl['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Polish:'.format(df_pl['page_title'][i], df_pl['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_pl2.append((df_pl['caption_reference_description'][i],generated_text))

len(captions_pl)
# Out:
# 758

# %%
with open('/content/drive/My Drive/ErwModul_24/results/pl_context_transl.txt', 'w') as writefile:
    for cap in captions_pl:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/pl_context.txt', 'w') as writefile:
    for cap in captions_pl2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate results for Portuguese

# %%
df_pt = df[df['language'] == 'pt'].reset_index()
df_pt
# Out:
#      index  Unnamed: 0 language  \
# 0     6720        6720       pt
# 1     6721        6721       pt
# 2     6722        6722       pt
# 3     6723        6723       pt
# 4     6724        6724       pt
# ..     ...         ...      ...
# 835   7555        7555       pt
# 836   7556        7556       pt
# 837   7557        7557       pt
# 838   7558        7558       pt
# 839   7559        7559       pt
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0    A confluência do Cuando (no centro, esquerda) ...
# 1                            Braga do Monte do Picoto.
# 2                            Mapa topográfico da Suíça
# 3    Casa numa pintura de Ettore Roesler Franz (c.1...
# 4    No debate de sua posse como presidenta da Comu...
# ..                                                 ...
# 835  O Eiger e o Mönch vistos de perto do Kleine Sc...
# 836         Pátio interior do Palazzo Medici Riccardi.
# 837            Centro de Edmonton, capital de Alberta.
# 838                           Vista aérea de Vancouver
# 839  Vladimir Putin é o Comandante Supremo das Forç...
#
#                     page_title                               section_title
# 0                   Rio Cuando                                Bibliografia
# 1                        Braga            Fotografias e vistas panorâmicas
# 2                        Suíça                                   Geografia
# 3    Casa di Ettore Fieramosca                                    História
# 4           Cristina Cifuentes         Presidência da Comunidade de Madrid
# ..                         ...                                         ...
# 835                      Eiger                                   Descrição
# 836    Palazzo Medici Riccardi  O museu dos Médici e a época contemporânea
# 837                    Alberta                                  Municípios
# 838                  Vancouver                                   Geografia
# 839             Vladimir Putin    Relações com as ex-Repúblicas Soviéticas
#
# [840 rows x 7 columns]

# %%
captions_pt = []
captions_pt2 = []
for i in range(0, 800):
  img_url = df_pt['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Título da página: {}, Seção Título: {}. Caption a imagem:'.format(df_pt['page_title'][i], df_pt['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_pt.append((df_pt['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Portuguese:'.format(df_pt['page_title'][i], df_pt['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_pt2.append((df_pt['caption_reference_description'][i],generated_text))

len(captions_pt)
# Out:
# 758

# %%
with open('/content/drive/My Drive/ErwModul_24/results/pt_context_transl.txt', 'w') as writefile:
    for cap in captions_pt:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/pt_context.txt', 'w') as writefile:
    for cap in captions_pt2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# ## Generate results for Traditional Chinese

# %%
df_zh_TW = df[df['language'] == 'zh-TW'].reset_index()
df_zh_TW
# Out:
#      index  Unnamed: 0 language  \
# 0     7560        7560    zh-TW
# 1     7561        7561    zh-TW
# 2     7562        7562    zh-TW
# 3     7563        7563    zh-TW
# 4     7564        7564    zh-TW
# ..     ...         ...      ...
# 835   8395        8395    zh-TW
# 836   8396        8396    zh-TW
# 837   8397        8397    zh-TW
# 838   8398        8398    zh-TW
# 839   8399        8399    zh-TW
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    http://upload.wikimedia.org/wikipedia/commons/...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  http://upload.wikimedia.org/wikipedia/commons/...
#
#                          caption_reference_description      page_title  \
# 0                         殷志源出席2016 MelOn Music Awards             殷志源
# 1    從這部成書於1407年以教會拉丁語寫成的聖經可以看出，這個古羅馬的語言對後世文化（主要指歐洲...             拉丁语
# 2                                           約1936年的科隆號         科隆号轻巡洋舰
# 3                                    2016年安徽各地級市地區生產總值  安徽各地级市地区生产总值列表
# 4                                               平底煱的培根              煙肉
# ..                                                 ...             ...
# 835                                  四合院被視為中國傳統文化的一部分。              文化
# 836                                         蘭桂坊酒店九如坊入口           蘭桂坊酒店
# 837                                               陶里克樓         青岛第十一中学
# 838  金庸批評中國不去收回蘇聯侵佔170萬平方公里的外東北（本圖）和外西北，卻要收回香港。有指這促...         金鐘 (編輯)
# 839                                         布納肯國家公園的珊瑚         布纳肯国家公园
#
#     section_title
# 0          水晶男孩重組
# 1           晚期拉丁語
# 2         第二次世界大戰
# 3           2016年
# 4            健康風險
# ..            ...
# 835          中文詞源
# 836          酒店設施
# 837          陶里克樓
# 838    後人分析金庸與鄧小平
# 839           生物群
#
# [840 rows x 7 columns]

# %%
captions_zh_TW = []
captions_zh_TW2 = []
for i in range(0, 800):
  img_url = df_zh_TW['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = '頁面標題: {},部分標題: {}. 字幕圖片:'.format(df_zh_TW['page_title'][i], df_zh_TW['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_zh_TW.append((df_zh_TW['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Chinese (Traditional):'.format(df_zh_TW['page_title'][i], df_zh_TW['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_zh_TW2.append((df_zh_TW['caption_reference_description'][i],generated_text))

len(captions_zh_TW)
# Out:
# 748

# %%
with open('/content/drive/My Drive/ErwModul_24/results/zh_TW_context_transl.txt', 'w') as writefile:
    for cap in captions_zh_TW:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/zh_TW_context.txt', 'w') as writefile:
    for cap in captions_zh_TW2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

# %% [markdown]
# # Half-Time

# %% [markdown]
# ## Generate results for Simplified Chinese

# %%
df_zh = df[df['language'] == 'zh'].reset_index()
df_zh
# Out:
#      index  Unnamed: 0 language  \
# 0     8400        8400       zh
# 1     8401        8401       zh
# 2     8402        8402       zh
# 3     8403        8403       zh
# 4     8404        8404       zh
# ..     ...         ...      ...
# 835   9235        9235       zh
# 836   9236        9236       zh
# 837   9237        9237       zh
# 838   9238        9238       zh
# 839   9239        9239       zh
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                caption_reference_description      page_title section_title
# 0                                       庄周梦蝶              庄子          文学贡献
# 1                                        申公豹        封神演義角色列表          二代弟子
# 2                      瑞士卢塞恩，接触网维修工程车正在抢修接触网            無軌電車            缺点
# 3                                    卡祖笛组装步骤             卡祖笛            历史
# 4                     1998年，正在庆祝成为双冠王的阿森纳女子队      阿森纳女子足球俱乐部          主场球场
# ..                                       ...             ...           ...
# 835  配属上海机务段(沪)的和谐1D型电力机车第0147号牵引K79次列车进入株洲站       K79/80次列车          机车交路
# 836      数字相机用点色数来描述屏幕的精细程度，每个像素包含了红绿蓝三个点色数。           每英寸像素          数字相机
# 837                                 船上的花园及酒吧       喬治·華盛頓號郵輪         设计及建造
# 838            1941年3月，义军的M13/40坦克于的黎波里的街道上。        M13/40坦克         初次的行动
# 839                          英特尔公布的“IA”核心架构图  Intel Larrabee     x86“IA”核心
#
# [840 rows x 7 columns]

# %%
captions_zh = []
captions_zh2 = []
for i in range(0, 800):
  img_url = df_zh['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = '页面标题: {},部分标题: {}. 字幕图像:'.format(df_zh['page_title'][i], df_zh['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_zh.append((df_zh['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Chinese (Simplified):'.format(df_zh['page_title'][i], df_zh['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_zh2.append((df_zh['caption_reference_description'][i],generated_text))

len(captions_zh)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/conv.py:456: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return F.conv2d(input, weight, bias, self.stride,
# 740

# %%
with open('/content/drive/My Drive/ErwModul_24/results/zh_context_transl.txt', 'w') as writefile:
    for cap in captions_zh:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/zh_context.txt', 'w') as writefile:
    for cap in captions_zh2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/zh_context_transl.txt', 'w') as writefile:
    for cap in captions_zh:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/zh_context.txt', 'w') as writefile:
    for cap in captions_zh2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Ukrainian

# %%
df_uk = df[df['language'] == 'uk'].reset_index()
df_uk
# Out:
#      index  Unnamed: 0 language  \
# 0     9240        9240       uk
# 1     9241        9241       uk
# 2     9242        9242       uk
# 3     9243        9243       uk
# 4     9244        9244       uk
# ..     ...         ...      ...
# 835  10075       10075       uk
# 836  10076       10076       uk
# 837  10077       10077       uk
# 838  10078       10078       uk
# 839  10079       10079       uk
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0           Вид на озеро Севан із траси Єреван—Тбілісі
# 1                              Крабоподібна туманність
# 2    Ганс Тільковскі у матчі групового етапу чемпіо...
# 3                  Комплекс до перебудови. Фото 1870-х
# 4                            Ден Хармон, автор серіалу
# ..                                                 ...
# 835                           Замок Tyresö в 1661 році
# 836  Староакадемічний корпус НаУКМА, де розташована...
# 837                        Пляж Аркадія ранньою весною
# 838  Голосування в виборчому окрузі № 70 в Оломоуці...
# 839          Дягель лікарський (Angelica archangelica)
#
#                                             page_title       section_title
# 0                                        Севан (озеро)           Узбережжя
# 1                     Астрономія у Стародавньому Китаї        Відомі факти
# 2                                      Ганс Тільковскі   Виступи за збірну
# 3    Комплекс монастиря та костелу бернардинів (Луцьк)          Перебудова
# 4                               Спільнота (телесеріал)             Критика
# ..                                                 ...                 ...
# 835                                   Марія Їллєншерна           Біографія
# 836  Національний університет «Києво-Могилянська ак...  Наукова бібліотека
# 837                          Приморський район (Одеса)  Загальні відомості
# 838                        Вибори до Сенату Чехії 2018          Результати
# 839                                             Дягель           Поширення
#
# [840 rows x 7 columns]

# %%
captions_uk = []
captions_uk2 = []
for i in range(0, 800):
  img_url = df_uk['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Назва сторінки: {}, розділ Назва: {}. Підголовка зображення:'.format(df_uk['page_title'][i], df_uk['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_uk.append((df_uk['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Ukrainian:'.format(df_uk['page_title'][i], df_uk['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_uk2.append((df_uk['caption_reference_description'][i],generated_text))

len(captions_uk)
# Out:
# 747

# %%
with open('/content/drive/My Drive/ErwModul_24/results/uk_context_transl.txt', 'w') as writefile:
    for cap in captions_uk:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/uk_context.txt', 'w') as writefile:
    for cap in captions_uk2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/uk_context_transl.txt', 'w') as writefile:
    for cap in captions_uk:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/uk_context.txt', 'w') as writefile:
    for cap in captions_uk2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Dutch

# %%
df_nl = df[df['language'] == 'nl'].reset_index()
df_nl
# Out:
#      index  Unnamed: 0 language  \
# 0    10080       10080       nl
# 1    10081       10081       nl
# 2    10082       10082       nl
# 3    10083       10083       nl
# 4    10084       10084       nl
# ..     ...         ...      ...
# 835  10915       10915       nl
# 836  10916       10916       nl
# 837  10917       10917       nl
# 838  10918       10918       nl
# 839  10919       10919       nl
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0    Grafkapel van de familie De Smeth te Alphen aa...
# 1                              Keizerin Maria Theresia
# 2                Timo Mäkinen\noverleden op 4 mei 2017
# 3    Een jong dat de inkeping boven de vestibule va...
# 4    Thomas Isaacq (?-1539-40) (knielend op het lin...
# ..                                                 ...
# 835                         dagbouw Schöningen in 2012
# 836      Zicht op het federaal paleis in Bern in 1857.
# 837  satellietfoto, die de vorming van meren toont ...
# 838  De Amateurtuindersvereniging Utrecht-Zuid best...
# 839                           Herbert Marcuse\n29 juli
#
#                                         page_title               section_title
# 0                                         De Smeth               Enkele telgen
# 1                         Geschiedenis van Brussel  Van Spanje naar Oostenrijk
# 2    Lijst van personen overleden in 2017/Voorstel                         Mei
# 3                                     Pinacosaurus   Onderscheidende kenmerken
# 4                                      Wapenkoning                   Nederland
# ..                                             ...                         ...
# 835                             Dagbouw Schöningen                Externe link
# 836                   Geschiedenis van Zwitserland  Federale grondwet van 1848
# 837         Terugtrekking van gletsjers sinds 1850                        Azië
# 838                             Lunetten (Utrecht)                       Groen
# 839           Lijst van personen overleden in 1979                        Juli
#
# [840 rows x 7 columns]

# %%
captions_nl = []
captions_nl2 = []
for i in range(0, 800):
  img_url = df_nl['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Titel pagina: {}, sectie titel: {}. Onderschrift van de afbeelding:'.format(df_nl['page_title'][i], df_nl['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_nl.append((df_nl['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Dutch:'.format(df_nl['page_title'][i], df_nl['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_nl2.append((df_nl['caption_reference_description'][i],generated_text))

len(captions_nl)
# Out:
# 767

# %%
with open('/content/drive/My Drive/ErwModul_24/results/nl_context_transl.txt', 'w') as writefile:
    for cap in captions_nl:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/nl_context.txt', 'w') as writefile:
    for cap in captions_nl2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/nl_context_transl.txt', 'w') as writefile:
    for cap in captions_nl:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/nl_context.txt', 'w') as writefile:
    for cap in captions_nl2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Czech

# %%
df_cs = df[df['language'] == 'cs'].reset_index()
df_cs
# Out:
#      index  Unnamed: 0 language  \
# 0    10920       10920       cs
# 1    10921       10921       cs
# 2    10922       10922       cs
# 3    10923       10923       cs
# 4    10924       10924       cs
# ..     ...         ...      ...
# 835  11755       11755       cs
# 836  11756       11756       cs
# 837  11757       11757       cs
# 838  11758       11758       cs
# 839  11759       11759       cs
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    http://upload.wikimedia.org/wikipedia/commons/...
# ..                                                 ...
# 835  http://upload.wikimedia.org/wikipedia/commons/...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  http://upload.wikimedia.org/wikipedia/commons/...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                                          Psychrometr
# 1                               Krakovský groš (avers)
# 2                                        Srbské okresy
# 3                                    Autoportrét, 1962
# 4                             Schéma schránky rozsivek
# ..                                                 ...
# 835                              Slovenský Národný Dom
# 836                                       Hlava trubce
# 837                    Nákres ponorky Sankt Petersburg
# 838        Reliéf postavy na Tichém náměstí v Třebíči.
# 839  Dům ředitele spořitelny V. Mezery v Orlové, zn...
#
#                    page_title                  section_title
# 0                 Psychrometr           Augustův psychrometr
# 1                        Groš                         Odkazy
# 2                      Srbsko  Administrativní dělení Srbska
# 3          Jean-Louis Swiners        Fotograf a fotoreportér
# 4                    Rozsivky             Základní informace
# ..                        ...                            ...
# 835                     Kysáč                       Historie
# 836                    Trubec                  Vzhled trubce
# 837          Projekt 677 Lada                  Pozadí vzniku
# 838  Jiří Svoboda (výtvarník)                      Biografie
# 839                   Slezané                     „Šlonzáci“
#
# [840 rows x 7 columns]

# %%
captions_cs = []
captions_cs2 = []
for i in range(0, 800):
  img_url = df_cs['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Název stránky: {}, Sekce Název: {}. Podpis obrázku:'.format(df_cs['page_title'][i], df_cs['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_cs.append((df_cs['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Czech:'.format(df_cs['page_title'][i], df_cs['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_cs2.append((df_cs['caption_reference_description'][i],generated_text))

len(captions_cs)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# 767

# %%
with open('/content/drive/My Drive/ErwModul_24/results/cs_context_transl.txt', 'w') as writefile:
    for cap in captions_cs:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/cs_context.txt', 'w') as writefile:
    for cap in captions_cs2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/cs_context_transl.txt', 'w') as writefile:
    for cap in captions_cs:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/cs_context.txt', 'w') as writefile:
    for cap in captions_cs2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Catalan

# %%
df_ca = df[df['language'] == 'ca'].reset_index()
df_ca
# Out:
#      index  Unnamed: 0 language  \
# 0    11760       11760       ca
# 1    11761       11761       ca
# 2    11762       11762       ca
# 3    11763       11763       ca
# 4    11764       11764       ca
# ..     ...         ...      ...
# 835  12595       12595       ca
# 836  12596       12596       ca
# 837  12597       12597       ca
# 838  12598       12598       ca
# 839  12599       12599       ca
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  http://upload.wikimedia.org/wikipedia/commons/...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0    Una al·legoria medieval comú de la follia, pin...
# 1    Josep i la dona de Putifar, cap a 1645, oli so...
# 2                              Anatoli Papànov el 1942
# 3    Desembussador amb bomba d'alta pressió profess...
# 4                              Antiga Casa de la Vila.
# ..                                                 ...
# 835  Exèrcit rus (1756-1762), incloent-hi un granad...
# 836                   Entrega Premi Ferran Termes 2015
# 837  Soldat de l'Afrika Korps, protegint-se de les ...
# 838  Sala principal del museu amb funció de distrib...
# 839                        The Dahabshiil in Hargeisa.
#
#                             page_title                          section_title
# 0                              El Boig                     Com a trumfo major
# 1            Bartolomé Esteban Murillo           Recepció i valoració crítica
# 2                      Anatoli Papànov  Primers anys i la guerra amb Alemanya
# 3                  Desembussador actiu                Desembussadors mecànics
# 4                    Mollet del Vallès              Lloc i edificis d'interès
# ..                                 ...                                    ...
# 835   Història dels uniformes militars                            Segle XVIII
# 836    Jaume Alonso-Cuevillas i Sayrol                              Biografia
# 837                               Heer          La campanya del nord d'Àfrica
# 838  Museu Nacional d'Art de Catalunya                  75è aniversari (2009)
# 839                            Somàlia                               Economia
#
# [840 rows x 7 columns]

# %%
captions_ca = []
captions_ca2 = []
for i in range(0, 800):
  img_url = df_ca['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Titull de pàgina: {}, Secció Titull: {}. Capció de la imatge:'.format(df_ca['page_title'][i], df_ca['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ca.append((df_ca['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Catalan:'.format(df_ca['page_title'][i], df_ca['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ca2.append((df_ca['caption_reference_description'][i],generated_text))

len(captions_ca)
# Out:
# 765

# %%
with open('/content/drive/My Drive/ErwModul_24/results/ca_context_transl.txt', 'w') as writefile:
    for cap in captions_ca:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/ca_context.txt', 'w') as writefile:
    for cap in captions_ca2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/ca_context_transl.txt', 'w') as writefile:
    for cap in captions_ca:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/ca_context.txt', 'w') as writefile:
    for cap in captions_ca2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Hungarian

# %%
df_hu = df[df['language'] == 'hu'].reset_index()
df_hu
# Out:
#      index  Unnamed: 0 language  \
# 0    12600       12600       hu
# 1    12601       12601       hu
# 2    12602       12602       hu
# 3    12603       12603       hu
# 4    12604       12604       hu
# ..     ...         ...      ...
# 835  13435       13435       hu
# 836  13436       13436       hu
# 837  13437       13437       hu
# 838  13438       13438       hu
# 839  13439       13439       hu
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                             Az állat rekonstrukciója
# 1                              Ezana felirata Meroéban
# 2    A Crait bolygón játszódó csatajeleneteket Sala...
# 3                            Az Északi Flotta jelvénye
# 4                                       Eugene Bullard
# ..                                                 ...
# 835  Mivel a tartósítási módszerek során a különböz...
# 836         Németországi fellépése, 2014. július 19-én
# 837  A HMS Calcutta (1831) galériája (Portsmouth), ...
# 838                         A rendészeti iroda avatása
# 839  Marcus Aurelius mellszobra, Capitolium Múzeumo...
#
#                                      page_title             section_title
# 0                                      Baryonyx               Megjelenése
# 1                          Ezana akszúmi király               Külpolitika
# 2                    Star Wars: Az utolsó Jedik       Gyártás és forgatás
# 3    Az Oroszországi Föderáció katonai körzetei          Az Északi Flotta
# 4                      Hadiérem (Franciaország)   Nevezetes kitüntetettek
# ..                                          ...                       ...
# 835                                  Koboldcápa   Rendszertani besorolása
# 836                                   Anastacia  Resurrection (2014–2015)
# 837                             Rudyard Kipling   Gyermekkora és ifjúsága
# 838                                     Solymár            Mentőszolgálat
# 839               Marcus Aurelius római császár              Társuralkodó
#
# [840 rows x 7 columns]

# %%
captions_hu = []
captions_hu2 = []
for i in range(0, 800):
  img_url = df_hu['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Oldalakcím: {}, szakaszcím: {}. A kép aláírása:'.format(df_hu['page_title'][i], df_hu['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_hu.append((df_hu['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Hungarian:'.format(df_hu['page_title'][i], df_hu['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_hu2.append((df_hu['caption_reference_description'][i],generated_text))

len(captions_hu)
# Out:
# 665

# %%
with open('/content/drive/My Drive/ErwModul_24/results/hu_context_transl.txt', 'w') as writefile:
    for cap in captions_hu:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/hu_context.txt', 'w') as writefile:
    for cap in captions_hu2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/hu_context_transl.txt', 'w') as writefile:
    for cap in captions_hu:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/hu_context.txt', 'w') as writefile:
    for cap in captions_hu2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Arabic

# %%
df_ar = df[df['language'] == 'ar'].reset_index()
df_ar
# Out:
#      index  Unnamed: 0 language  \
# 0    13440       13440       ar
# 1    13441       13441       ar
# 2    13442       13442       ar
# 3    13443       13443       ar
# 4    13444       13444       ar
# ..     ...         ...      ...
# 835  14275       14275       ar
# 836  14276       14276       ar
# 837  14277       14277       ar
# 838  14278       14278       ar
# 839  14279       14279       ar
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    http://upload.wikimedia.org/wikipedia/commons/...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                فرديناند الثاني، إمبراطور روماني مقدس
# 1                        خربة قمران قرب أريحا، فلسطين.
# 2                                       يقطينات هالوين
# 3    خريطة لمستخدمون الحاليون لإم-48 باتون باللون ا...
# 4                      مخطوطة يصف فيها الإدريسي فنلندا
# ..                                                 ...
# 835                                     نبتة الزعيتيرة
# 836  خريطة تصويت النواب على التعديل الذي يمدد زواج ...
# 837  الأمير محمد بن نايف آل سعود مع وزيرة الخارجية ...
# 838                       مبنى مشرعين ولاية رود آيلاند
# 839  ثكنات عسكرية إسبانية في تفاريتي سيطر عليها الم...
#
#                              page_title                       section_title
# 0               الانتخابات الإمبراطورية                       انتخابات 1619
# 1                           البحر الميت                             التاريخ
# 2                                  خريف                          الارتباطات
# 3                           إم-48 باتون                          المستخدمون
# 4                              الإدريسي                               نشأته
# ..                                  ...                                 ...
# 835                           الزعيتيرة                 صور لنبتة الزعيتيرة
# 836   زواج المثليين في أيرلندا الشمالية  التقنين عبر برلمان وستمنستر (2019)
# 837  محمد بن نايف بن عبد العزيز آل سعود                        ولايته للعهد
# 838                          رود آيلاند                    القانون والحكومة
# 839                     الصحراء الغربية                              النزاع
#
# [840 rows x 7 columns]

# %%
captions_ar = []
captions_ar2 = []
for i in range(0, 800):
  img_url = df_ar['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'عنوان الصفحة: {}، عنوان القسم: {}. تسمية توضيحية للصورة:'.format(df_ar['page_title'][i], df_ar['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ar.append((df_ar['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Arabic:'.format(df_ar['page_title'][i], df_ar['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_ar2.append((df_ar['caption_reference_description'][i],generated_text))

len(captions_ar)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/TiffImagePlugin.py:858: UserWarning: Corrupt EXIF data.  Expecting to read 2 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:3167: DecompressionBombWarning: Image size (104043720 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# 731

# %%
with open('/content/drive/My Drive/ErwModul_24/results/ar_context_transl.txt', 'w') as writefile:
    for cap in captions_ar:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/ar_context.txt', 'w') as writefile:
    for cap in captions_ar2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/ar_context_transl.txt', 'w') as writefile:
    for cap in captions_ar:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/ar_context.txt', 'w') as writefile:
    for cap in captions_ar2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Hebrew

# %%
df_iw = df[df['language'] == 'iw'].reset_index()
df_iw
# Out:
#      index  Unnamed: 0 language  \
# 0    14280       14280       iw
# 1    14281       14281       iw
# 2    14282       14282       iw
# 3    14283       14283       iw
# 4    14284       14284       iw
# ..     ...         ...      ...
# 835  15115       15115       iw
# 836  15116       15116       iw
# 837  15117       15117       iw
# 838  15118       15118       iw
# 839  15119       15119       iw
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  https://upload.wikimedia.org/wikipedia/commons...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0                                             דגל הצבא
# 1                          וושינגטון בגיל ארבעים, 1772
# 2    במעגל הקווינטות ניתן לראות שכל שלושה צעדים ימי...
# 3    שורשים של המשוואה לרמות אנרגיה מקוונטטות בבור ...
# 4                            בניית תא שיט בתעלה ב-1906
# ..                                                 ...
# 835  מראה בתצוגה "הסודות הכמוסים של בון", המוזיאון ...
# 836  המתאבק ולנטין רייצ'ב (למטה), במהלך קרב הגמר במ...
# 837  נס קצין בכיר, לו היה זכאי לשם בתפקידו כמפקד שי...
# 838  מבצר קופשטיין, בתמונה משנת 1889 מאת הצייר הפול...
# 839  יארומיר יאגר נואם בפראג בקבלת הפנים לנבחרת צ'כ...
#
#                      page_title                         section_title
# 0    הכוחות המזוינים של סלובניה                              היסטוריה
# 1              ג'ורג' וושינגטון  בין המלחמות: מאונט ורנון (1759–1774)
# 2                     סולם יחסי                        ניתוח ודוגמאות
# 3             בור פוטנציאל סופי    מציאת פונקציות הגל עבור המצב הקשור
# 4       הפארק הלאומי אוורגליידס                   פיתוח הקרקע ושימורה
# ..                          ...                                   ...
# 835                בון (קומיקס)                                 עלילה
# 836  בולגריה במשחקים האולימפיים              אולימפיאדת מוסקבה (1980)
# 837                   ישראל לשם                פיקוד על שייטת הצוללות
# 838    אן-ז'וזף טרואן דה מריקור                         ההגליה והמעצר
# 839                יארומיר יאגר                      בזירה הבינלאומית
#
# [840 rows x 7 columns]

# %%
captions_iw = []
captions_iw2 = []
for i in range(0, 800):
  img_url = df_iw['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'כותרת עמוד: {}, כותרת מקטע: {}. כיתוב התמונה:'.format(df_iw['page_title'][i], df_iw['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_iw.append((df_iw['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Hebrew:'.format(df_iw['page_title'][i], df_iw['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_iw2.append((df_iw['caption_reference_description'][i],generated_text))

len(captions_iw)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:3167: DecompressionBombWarning: Image size (93945348 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 768

# %%
with open('/content/drive/My Drive/ErwModul_24/results/iw_context_transl.txt', 'w') as writefile:
    for cap in captions_iw:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/iw_context.txt', 'w') as writefile:
    for cap in captions_iw2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/iw_context_transl.txt', 'w') as writefile:
    for cap in captions_iw:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/iw_context.txt', 'w') as writefile:
    for cap in captions_iw2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Swedish

# %%
df_sv = df[df['language'] == 'sv'].reset_index()
df_sv
# Out:
#      index  Unnamed: 0 language  \
# 0    15120       15120       sv
# 1    15121       15121       sv
# 2    15122       15122       sv
# 3    15123       15123       sv
# 4    15124       15124       sv
# ..     ...         ...      ...
# 835  15955       15955       sv
# 836  15956       15956       sv
# 837  15957       15957       sv
# 838  15958       15958       sv
# 839  15959       15959       sv
#
#                                              image_url  \
# 0    http://upload.wikimedia.org/wikipedia/commons/...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    http://upload.wikimedia.org/wikipedia/commons/...
# 4    http://upload.wikimedia.org/wikipedia/commons/...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  http://upload.wikimedia.org/wikipedia/commons/...
# 839  http://upload.wikimedia.org/wikipedia/commons/...
#
#                          caption_reference_description             page_title  \
# 0                           Bilden visar en cotehardie             Tudortiden
# 1                                 Sängkammarinteriören  Clason-Hebbeska huset
# 2    Lastning av spannmål på ett kinesiskt bulkfart...                   Hamn
# 3         Ett montage som visar hur tennfigurer gjuts.              Tennfigur
# 4              I Port Moody, British Columbia, Kanada.         Grå strömstare
# ..                                                 ...                    ...
# 835        Vattenfall och "Jerusalems kvarm i Röttleån          Gränna socken
# 836         Olaus Magnus karta Carta Marina från 1539.                Valross
# 837                     Utrikesminister Daniel Webster       Millard Fillmore
# 838                               Landegode fyr, Bodø.          Fyrar i Norge
# 839        Bo Kaspers orkester med Bo i hatt i mitten.           Bo Sundström
#
#                      section_title
# 0                             Mode
# 1                   Interiörbilder
# 2                          Sverige
# 3                     Tillverkning
# 4                Utseende och läte
# ..                             ...
# 835                       Geografi
# 836        Valrossen och människan
# 837                      Ministrar
# 838                       Nordland
# 839  Som soloartist (Bo Sundström)
#
# [840 rows x 7 columns]

# %%
captions_sv = []
captions_sv2 = []
for i in range(0, 800):
  img_url = df_sv['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Sidans titel: {}, avsnittets titel: {}. Bildtext till bilden:'.format(df_sv['page_title'][i], df_sv['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_sv.append((df_sv['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Swedish:'.format(df_sv['page_title'][i], df_sv['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_sv2.append((df_sv['caption_reference_description'][i],generated_text))

len(captions_sv)
# Out:
# 765

# %%
with open('/content/drive/My Drive/ErwModul_24/results/sv_context_transl.txt', 'w') as writefile:
    for cap in captions_sv:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/sv_context.txt', 'w') as writefile:
    for cap in captions_sv2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/sv_context_transl.txt', 'w') as writefile:
    for cap in captions_sv:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/sv_context.txt', 'w') as writefile:
    for cap in captions_sv2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

# %% [markdown]
# ## Generate results for Vietnamese

# %%
df_vi = df[df['language'] == 'vi'].reset_index()
df_vi
# Out:
#      index  Unnamed: 0 language  \
# 0    15960       15960       vi
# 1    15961       15961       vi
# 2    15962       15962       vi
# 3    15963       15963       vi
# 4    15964       15964       vi
# ..     ...         ...      ...
# 835  16795       16795       vi
# 836  16796       16796       vi
# 837  16797       16797       vi
# 838  16798       16798       vi
# 839  16799       16799       vi
#
#                                              image_url  \
# 0    https://upload.wikimedia.org/wikipedia/commons...
# 1    https://upload.wikimedia.org/wikipedia/commons...
# 2    https://upload.wikimedia.org/wikipedia/commons...
# 3    https://upload.wikimedia.org/wikipedia/commons...
# 4    https://upload.wikimedia.org/wikipedia/commons...
# ..                                                 ...
# 835  https://upload.wikimedia.org/wikipedia/commons...
# 836  https://upload.wikimedia.org/wikipedia/commons...
# 837  https://upload.wikimedia.org/wikipedia/commons...
# 838  http://upload.wikimedia.org/wikipedia/commons/...
# 839  https://upload.wikimedia.org/wikipedia/commons...
#
#                          caption_reference_description  \
# 0    Trao đổi nhiệt qua bộ trung gian, kết hợp dự t...
# 1    Tháp Luân Đôn là một lâu đài thời trung cổ lịc...
# 2    Lothar Matthäus đã chơi 25 trận đấu World Cup ...
# 3    Thành Châu Đốc trong bản đồ Nam Kỳ Lục Tỉnh (B...
# 4                                          Joan Smalls
# ..                                                 ...
# 835  Núi Sugarloaf, Rio de Janeiro được sử dụng cho...
# 836                                      Septic river.
# 837                            Phục nguyên P. grangeri
# 838  Một góc thành phố Huế bị tàn phá trơ trụi. Ảnh...
# 839          1 cặp chim sếu với chim non tại Velavadar
#
#                                     page_title  \
# 0                           Trao đổi địa nhiệt
# 1                                     Luân Đôn
# 2                Giải vô địch bóng đá thế giới
# 3                                     Châu Đốc
# 4    Danh sách người mẫu của Victoria's Secret
# ..                                         ...
# 835                         The Amazing Race 2
# 836                               Ô nhiễm biển
# 837                               Platybelodon
# 838                       Sự kiện Tết Mậu Thân
# 839                                  Sếu sarus
#
#                                          section_title
# 0                          Dùng bộ trao đổi trung gian
# 1                                            Kiến trúc
# 2                               Các kỷ lục và thống kê
# 3                                    Nguồn gốc tên gọi
# 4    Người mẫu xuất hiện trong các show của Victori...
# ..                                                 ...
# 835                          Chặng 1 (Hoa Kỳ → Brasil)
# 836                                 Nguồn xả trực tiếp
# 837                                              Mô tả
# 838                                            Tại Huế
# 839                                     Yếu tố tử vong
#
# [840 rows x 7 columns]

# %%
captions_vi = []
captions_vi2 = []
for i in range(0, 800):
  img_url = df_vi['image_url'][i]
  try:
    img_path, _ = urllib.request.urlretrieve(img_url)

    # load image
    image = Image.open(img_path).convert('RGB')
  except:
    continue

  prompt = 'Trang tiêu đề: {}, Phần tiêu đề: {}. Đăng chú ý hình ảnh:'.format(df_vi['page_title'][i], df_vi['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_vi.append((df_vi['caption_reference_description'][i],generated_text))

  prompt = 'Page Title: {}, Section Title: {}. Caption the image in Vietnamese:'.format(df_vi['page_title'][i], df_vi['section_title'][i])
  inputs = processor(image, text=prompt, return_tensors='pt').to(device, torch.float16)

  generated_ids = model.generate(**inputs, max_new_tokens=30)
  generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0].strip()
  captions_vi2.append((df_vi['caption_reference_description'][i],generated_text))

len(captions_vi)
# Out:
# 735

# %%
with open('/content/drive/My Drive/ErwModul_24/results/vi_context_transl.txt', 'w') as writefile:
    for cap in captions_vi:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/vi_context.txt', 'w') as writefile:
    for cap in captions_vi2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n|||\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/vi_context_transl.txt', 'w') as writefile:
    for cap in captions_vi:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')

with open('/content/drive/My Drive/ErwModul_24/results/backup/vi_context.txt', 'w') as writefile:
    for cap in captions_vi2:
        writefile.write(cap[0]+'\n')
        writefile.write('|\n')
        writefile.write(cap[1]+'\n\n')
