# %% [markdown]
# # Read dataset

# %%
import pandas as pd
from collections import Counter

# %%
path = 'data/wit_v1.train.all-1percent_sample.tsv'

# %%
df = pd.read_csv(path, sep='\t')
df
# Out:
#        language                                           page_url
# 0            es       https://es.wikipedia.org/wiki/Hoz_y_martillo  \
# 1            de    https://de.wikipedia.org/wiki/Kleines_Hasenmaul
# 2            ru  https://ru.wikipedia.org/wiki/%D0%A3%D0%BA%D1%...
# 3            ru  https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%...
# 4            sw  https://sw.wikipedia.org/wiki/Brookline,_Massa...
# ...         ...                                                ...
# 370368       en    https://en.wikipedia.org/wiki/Suillus_quiescens
# 370369       fa  https://fa.wikipedia.org/wiki/%D8%A7%DA%A9%DB%...
# 370370       de  https://de.wikipedia.org/wiki/Fauler_See_(Schw...
# 370371       ko  https://ko.wikipedia.org/wiki/%EB%8C%80%ED%95%...
# 370372       eo         https://eo.wikipedia.org/wiki/M%C3%B6nkloh
#
#                                                 image_url
# 0       https://upload.wikimedia.org/wikipedia/commons...  \
# 1       https://upload.wikimedia.org/wikipedia/commons...
# 2       https://upload.wikimedia.org/wikipedia/commons...
# 3       http://upload.wikimedia.org/wikipedia/commons/...
# 4       https://upload.wikimedia.org/wikipedia/commons...
# ...                                                   ...
# 370368  https://upload.wikimedia.org/wikipedia/commons...
# 370369  https://upload.wikimedia.org/wikipedia/commons...
# 370370  http://upload.wikimedia.org/wikipedia/commons/...
# 370371  https://upload.wikimedia.org/wikipedia/commons...
# 370372  https://upload.wikimedia.org/wikipedia/commons...
#
#                              page_title                section_title
# 0                        Hoz y martillo                     Emblemas  \
# 1                     Kleines Hasenmaul                          NaN
# 2                     Украинская гривна  Изъятые из обращения монеты
# 3       Менделеево (Московская область)                          NaN
# 4              Brookline, Massachusetts                          NaN
# ...                                 ...                          ...
# 370368                Suillus quiescens     Habitat and distribution
# 370369                        اکیر ترکی                          NaN
# 370370            Fauler See (Schwerin)                          NaN
# 370371                         대한출판문화협회                          NaN
# 370372                          Mönkloh                       Bildoj
#
#                                hierarchical_section_title
# 0                     Hoz y martillo / Galería / Emblemas  \
# 1                                       Kleines Hasenmaul
# 2       Украинская гривна / Монеты / Изъятые из обраще...
# 3                         Менделеево (Московская область)
# 4                                Brookline, Massachusetts
# ...                                                   ...
# 370368       Suillus quiescens / Habitat and distribution
# 370369                                          اکیر ترکی
# 370370                              Fauler See (Schwerin)
# 370371                                           대한출판문화협회
# 370372                                   Mönkloh / Bildoj
#
#                             caption_reference_description
# 0                                                     NaN  \
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4               Sehemu za Mji wa Brookline, Massachusetts
# ...                                                   ...
# 370368  S. quiescens forms mycorrhizal associations wi...
# 370369                                                NaN
# 370370                                                NaN
# 370371                  고영수 회장 (2015 서울국제도서전 개최 기념 기자간담회)
# 370372                                                NaN
#
#                           caption_attribution_description
# 0          Galego: Logo do Movemento Galego ao Socialismo  \
# 1       English: Lesser bulldog bat (Noctilio albivent...
# 2       English: Coin of Ukraine Русский: Юбилейная мо...
# 3                                     English: mendeleevo
# 4       English: Brookline MA August 2015 Photo Collage 2
# ...                                                   ...
# 370368  English: Pinus muricata at the Dundee Botanic ...
# 370369  Species&#160; Acorus calamus Family&#160; Acor...
# 370370  Lage der Seen in Schwerin, Position of the lak...
# 370371             한국어: 2015 서울국제도서전 개최 기념 기자간담회 (고영수 회장)
# 370372  Kunst im öffentlichen Raum in Mönkloh mit eine...
#
#        caption_alt_text_description   mime_type  original_height
# 0                               NaN  image/jpeg              107  \
# 1                               NaN  image/jpeg             1636
# 2                               NaN  image/jpeg              193
# 3                               NaN  image/jpeg             1877
# 4                               NaN  image/jpeg             1936
# ...                             ...         ...              ...
# 370368                          NaN  image/jpeg             2048
# 370369                          NaN  image/jpeg             1119
# 370370                          NaN   image/png              564
# 370371                          NaN  image/jpeg              323
# 370372                          NaN  image/jpeg             4000
#
#         original_width  is_main_image  attribution_passes_lang_id
# 0                  272          False                       False  \
# 1                 2000           True                       False
# 2                  200          False                        True
# 3                 2756           True                        True
# 4                 1936          False                       False
# ...                ...            ...                         ...
# 370368            1536          False                        True
# 370369            1650           True                       False
# 370370             988           True                        True
# 370371             365          False                        True
# 370372            6000          False                       False
#
#         page_changed_recently
# 0                        True  \
# 1                       False
# 2                        True
# 3                       False
# 4                        True
# ...                       ...
# 370368                  False
# 370369                  False
# 370370                   True
# 370371                  False
# 370372                  False
#
#                                  context_page_description
# 0       La hoz y el martillo es un símbolo que represe...  \
# 1       Das Kleine Hasenmaul ist eine Fledermausart au...
# 2       Гри́вна — национальная валюта Украины, названн...
# 3       Менделе́ево — посёлок городского типа Московск...
# 4       Brookline ni mji wa Marekani katika jimbo la M...
# ...                                                   ...
# 370368  Suillus quiescens is a pored mushroom of the g...
# 370369  اکیر ترکی نام یک سرده از گیاهان است.\nاین سرده...
# 370370  Der Faule See befindet sich in der mecklenburg...
# 370371  대한출판문화협회는 출판산업의 건전한 발전도모, 출판문화의 사명달성으로 문화 향상에 ...
# 370372  Mönkloh estas komunumo en Germanio. Ĝi troviĝa...
#
#                               context_section_description
# 0                                                     NaN
# 1       Das Kleine Hasenmaul (Noctilio albiventris) is...
# 2       С 1 июля 2018 года прекращён дополнительный вы...
# 3       Менделе́ево — посёлок городского типа Московск...
# 4       Brookline ni mji wa Marekani katika jimbo la M...
# ...                                                   ...
# 370368  Fruit bodies grow together in small groups on ...
# 370369  اکیر ترکی (نام علمی: Acorus) نام یک سرده از گی...
# 370370  Der Faule See befindet sich in der mecklenburg...
# 370371  대한출판문화협회는 출판산업의 건전한 발전도모, 출판문화의 사명달성으로 문화 향상에 ...
# 370372                                                NaN
#
# [370373 rows x 17 columns]

# %% [markdown]
# ## Keep only 3 relevant columns: language, image_url and caption_reference_description

# %%
df = df[['language', 'image_url', 'caption_reference_description']]
df.drop_duplicates(inplace=True)
df.head()
# Out:
# /var/folders/dk/2mmpl1696w1f60jjs6zrywj00000gn/T/ipykernel_21351/3408470919.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)
#   language                                          image_url
# 0       es  https://upload.wikimedia.org/wikipedia/commons...  \
# 1       de  https://upload.wikimedia.org/wikipedia/commons...
# 2       ru  https://upload.wikimedia.org/wikipedia/commons...
# 3       ru  http://upload.wikimedia.org/wikipedia/commons/...
# 4       sw  https://upload.wikimedia.org/wikipedia/commons...
#
#                caption_reference_description
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4  Sehemu za Mji wa Brookline, Massachusetts

# %% [markdown]
# ## Drop rows where `caption_reference_description` is NaN

# %%
df.dropna(subset=['caption_reference_description'], inplace=True, ignore_index=True)
# Out:
# /var/folders/dk/2mmpl1696w1f60jjs6zrywj00000gn/T/ipykernel_21351/1967990228.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=['caption_reference_description'], inplace=True, ignore_index=True)

# %%
df
# Out:
#        language                                          image_url
# 0            sw  https://upload.wikimedia.org/wikipedia/commons...  \
# 1            en  https://upload.wikimedia.org/wikipedia/commons...
# 2            hy  https://upload.wikimedia.org/wikipedia/commons...
# 3            de  https://upload.wikimedia.org/wikipedia/commons...
# 4            cs  https://upload.wikimedia.org/wikipedia/commons...
# ...         ...                                                ...
# 169283       nl  https://upload.wikimedia.org/wikipedia/commons...
# 169284       pt  https://upload.wikimedia.org/wikipedia/commons...
# 169285       ja  https://upload.wikimedia.org/wikipedia/commons...
# 169286       en  https://upload.wikimedia.org/wikipedia/commons...
# 169287       ko  https://upload.wikimedia.org/wikipedia/commons...
#
#                             caption_reference_description
# 0               Sehemu za Mji wa Brookline, Massachusetts
# 1                       Jayson Musson on October 29, 2007
# 2                                            Չիբո կապելլա
# 3       Die California Clipper in der Bucht von Manila...
# 4            Rozdělení kantonu Basilej v letech 1832-1833
# ...                                                   ...
# 169283                                       Markt te Laç
# 169284  Salvador foi totalmente afetada pelo blecaute ...
# 169285    ミンスクでの2月11〜12日の会談での ベラルーシ、ロシア、ドイツ、フランス、ウクライナの首脳
# 169286  S. quiescens forms mycorrhizal associations wi...
# 169287                  고영수 회장 (2015 서울국제도서전 개최 기념 기자간담회)
#
# [169288 rows x 3 columns]

# %% [markdown]
# ## Count the number of entries of each language

# %%
languages_count = Counter(df['language'])
languages_count
# Out:
# Counter({'en': 32486,
#          'de': 17343,
#          'es': 11069,
#          'fr': 9710,
#          'it': 6364,
#          'ja': 6207,
#          'ru': 5545,
#          'pl': 4294,
#          'zh-TW': 4184,
#          'zh': 4023,
#          'nl': 4012,
#          'sv': 3649,
#          'cs': 3358,
#          'pt': 3247,
#          'uk': 2819,
#          'ca': 2512,
#          'no': 2197,
#          'hu': 2128,
#          'fi': 1885,
#          'iw': 1765,
#          'vi': 1738,
#          'ar': 1704,
#          'sr': 1635,
#          'eo': 1505,
#          'id': 1493,
#          'fa': 1473,
#          'da': 1381,
#          'bg': 1380,
#          'ko': 1335,
#          'tr': 1251,
#          'ro': 1143,
#          'la': 1077,
#          'et': 1057,
#          'el': 942,
#          'gl': 933,
#          'ast': 886,
#          'hr': 776,
#          'sr-Latn': 718,
#          'hy': 714,
#          'sl': 703,
#          'eu': 663,
#          'nn': 659,
#          'lt': 633,
#          'sk': 610,
#          'mk': 604,
#          'ms': 564,
#          'th': 536,
#          'be': 529,
#          'ta': 505,
#          'bn': 501,
#          'ml': 466,
#          'lv': 444,
#          'af': 433,
#          'ur': 426,
#          'br': 425,
#          'hi': 424,
#          'bs': 415,
#          'ka': 360,
#          'az': 349,
#          'azb': 342,
#          'yue': 332,
#          'fy': 325,
#          'oc': 309,
#          'sco': 283,
#          'vo': 279,
#          'is': 262,
#          'ga': 248,
#          'sq': 247,
#          'kk': 242,
#          'lb': 239,
#          'be-tarask': 231,
#          'kn': 224,
#          'te': 200,
#          'sw': 199,
#          'cy': 195,
#          nan: 192,
#          'fil': 179,
#          'ba': 164,
#          'nds': 157,
#          'pa': 146,
#          'bar': 140,
#          'mr': 123,
#          'jv': 123,
#          'si': 111,
#          'lah': 100,
#          'my': 99,
#          'lmo': 96,
#          'tt': 94,
#          'io': 91,
#          'ne': 87,
#          'mn': 86,
#          'war': 83,
#          'an': 83,
#          'qu': 80,
#          'uz': 80,
#          'cv': 71,
#          'ckb': 71,
#          'arz': 70,
#          'tg': 66,
#          'xmf': 52,
#          'hsb': 52,
#          'mg': 48,
#          'vec': 38,
#          'ht': 35,
#          'nv': 35,
#          'ceb': 33,
#          'ce': 32,
#          'ia': 27})

# %% [markdown]
# ## Only keep the entries in top-10 languages

# %%
most_common_langs = [lang for lang, count in languages_count.most_common(10)]
most_common_langs
# Out:
# ['en', 'de', 'es', 'fr', 'it', 'ja', 'ru', 'pl', 'zh-TW', 'zh']

# %%
mask = df['language'].isin(most_common_langs)
df_most_common_langs = df[mask]
df_most_common_langs
# Out:
#        language                                          image_url
# 1            en  https://upload.wikimedia.org/wikipedia/commons...  \
# 3            de  https://upload.wikimedia.org/wikipedia/commons...
# 5         zh-TW  https://upload.wikimedia.org/wikipedia/commons...
# 6            fr  https://upload.wikimedia.org/wikipedia/commons...
# 9            en  http://upload.wikimedia.org/wikipedia/commons/...
# ...         ...                                                ...
# 169279       en  http://upload.wikimedia.org/wikipedia/commons/...
# 169280       en  https://upload.wikimedia.org/wikipedia/commons...
# 169282       fr  https://upload.wikimedia.org/wikipedia/commons...
# 169285       ja  https://upload.wikimedia.org/wikipedia/commons...
# 169286       en  https://upload.wikimedia.org/wikipedia/commons...
#
#                             caption_reference_description
# 1                       Jayson Musson on October 29, 2007
# 3       Die California Clipper in der Bucht von Manila...
# 5                                   展示在芝加哥菲爾德自然史博物館的兩頭食人獅
# 6       Plan de la Cité interdite. Les lettres en roug...
# 9       20–22 Marlborough Place, Brighton is roofed wi...
# ...                                                   ...
# 169279         The Kerr engine at the Anson Engine Museum
# 169280              Drawing of a 16th-century turtle ship
# 169282  Camille Saint-Saëns à la Salle Gaveau en 1913 ...
# 169285    ミンスクでの2月11〜12日の会談での ベラルーシ、ロシア、ドイツ、フランス、ウクライナの首脳
# 169286  S. quiescens forms mycorrhizal associations wi...
#
# [101225 rows x 3 columns]

# %% [markdown]
# ## Equal the number of entries of each language to the least frequent

# %%
num_of_least_frequent = languages_count.most_common(10)[-1][1]
num_of_least_frequent
# Out:
# 4023

# %%
sample_dfs = []
for lang in most_common_langs:
    sample_dfs.append(df_most_common_langs[df_most_common_langs['language'] == lang].sample(num_of_least_frequent))
df_sampled = pd.concat(sample_dfs, ignore_index=True)
df_sampled
# Out:
#       language                                          image_url
# 0           en  https://upload.wikimedia.org/wikipedia/commons...  \
# 1           en  https://upload.wikimedia.org/wikipedia/commons...
# 2           en  https://upload.wikimedia.org/wikipedia/commons...
# 3           en  https://upload.wikimedia.org/wikipedia/commons...
# 4           en  https://upload.wikimedia.org/wikipedia/commons...
# ...        ...                                                ...
# 40225       zh  https://upload.wikimedia.org/wikipedia/commons...
# 40226       zh  https://upload.wikimedia.org/wikipedia/commons...
# 40227       zh  https://upload.wikimedia.org/wikipedia/commons...
# 40228       zh  https://upload.wikimedia.org/wikipedia/commons...
# 40229       zh  http://upload.wikimedia.org/wikipedia/commons/...
#
#                            caption_reference_description
# 0                               Mount Ida and Azure Lake
# 1      The boundaries of the Byzantine Empire under J...
# 2       The east tower under construction in March 2019.
# 3                   U.S. professional golfer Nancy Lopez
# 4                            The chapel of Saint-Antoine
# ...                                                  ...
# 40225                                 京都大学理学研究科附属地球热学研究所
# 40226                                      位于首尔的韩国银行中央本部
# 40227                                               市镇详图
# 40228                                              南昌荟1楼
# 40229                                          满族摔跤手演练布库
#
# [40230 rows x 3 columns]

# %%
len(df_sampled) == num_of_least_frequent * 10
# Out:
# True

# %% [markdown]
# ## Save the resulting dataframe as the processed data to further use in **notebook name**

# %%
df_sampled.to_csv('data/preprocessed_wit_1_percent.tsv', sep='\t')
